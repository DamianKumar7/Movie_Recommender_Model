# %%
#Simple Recommndatin System and Content Based Recommendation System
#https://www.kaggle.com/tmdb/tmdb-movie-metadata  This is from where I have taken the dataset
import numpy as np
import pandas as pd

# %%
credits = pd.read_csv('tmdb_5000_credits.csv')
movies = pd.read_csv('tmdb_5000_movies.csv')

# %%
credits.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %%
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
credits.shape
# Out:
# (4803, 4)

# %%
movies.shape
# Out:
# (4803, 20)

# %%
credits_column_renamed = credits.rename(index=str, columns={"movie_id": "id"})
merged_df = movies.merge(credits_column_renamed,on= 'id')
merged_df.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4803 entries, 0 to 4802
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
# ...

# %%
cleaned_df = merged_df.drop(columns= ['title_x','title_y','revenue','homepage','status','budget'])

# %%
cleaned_df.head()
# Out:
#                                               genres      id  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   19995
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...     285
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  206647
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...   49026
# 4  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# ...

# %%
cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4803 entries, 0 to 4802
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   genres                4803 non-null   object
#  1   id                    4803 non-null   int64
#  2   keywords              4803 non-null   object
#  3   original_language     4803 non-null   object
#  4   original_title        4803 non-null   object
#  5   overview              4800 non-null   object
#  6   popularity            4803 non-null   float64
#  7   production_companies  4803 non-null   object
#  8   production_countries  4803 non-null   object
#  9   release_date          4802 non-null   object
#  10  runtime               4801 non-null   float64
#  11  spoken_languages      4803 non-null   object
#  12  tagline               3959 non-null   object
#  13  vote_average          4803 non-null   float64
#  14  vote_count            4803 non-null   int64
# ...

# %%
#Now we will use the weighted Mean Average
'''
IMDB uses this famous formula:

weighted rank (WR) = (v ÷ (v+m)) × R + (m ÷ (v+m)) × C
where 
R = average for the movie (mean) = (Rating)
v = number of votes for the movie = (votes)
m = minimum votes required to be listed in the Top 250 (currently 25,000)
C = the mean vote across the whole report
'''
# Out:
# '\nIMDB uses this famous formula:\n\nweighted rank (WR) = (v ÷ (v+m)) × R + (m ÷ (v+m)) × C\nwhere \nR = average for the movie (mean) = (Rating)\nv = number of votes for the movie = (votes)\nm = minimum votes required to be listed in the Top 250 (currently 25,000)\nC = the mean vote across the whole report\n'

# %%
v = cleaned_df['vote_count']
R = cleaned_df['vote_average']
C = cleaned_df['vote_average'].mean()
m = cleaned_df['vote_count'].quantile(0.7)

# %%
cleaned_df['weighted_average'] = ((R*v)+ (C*m))/(v+m)

# %%
cleaned_df.head()
# Out:
#                                               genres      id  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   19995
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...     285
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  206647
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...   49026
# 4  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# ...

# %%
sorted_ranking = cleaned_df.sort_values('weighted_average',ascending = False)
sorted_ranking[['original_title','popularity','vote_average','weighted_average']].head(20)
# Out:
#                                          original_title  popularity  \
# 1881                           The Shawshank Redemption  136.747729
# 3337                                      The Godfather  143.659698
# 662                                          Fight Club  146.757391
# 3232                                       Pulp Fiction  121.463076
# 65                                      The Dark Knight  187.322927
# 809                                        Forrest Gump  138.133331
# 1818                                   Schindler's List  104.469351
# 3865                                           Whiplash  192.528841
# 96                                            Inception  167.583710
# 1990                            The Empire Strikes Back   78.517830
# 2294                                           千と千尋の神隠し  118.968562
# 95                                         Interstellar  724.247784
# 2731                             The Godfather: Part II  105.792936
# ...

# %%
sorted_ranking = sorted_ranking.rename(index=str, columns={"original_title": "title"})
sorted_ranking.head()
# Out:
#                                                  genres   id  \
# 1881  [{"id": 18, "name": "Drama"}, {"id": 80, "name...  278
# 3337  [{"id": 18, "name": "Drama"}, {"id": 80, "name...  238
# 662                       [{"id": 18, "name": "Drama"}]  550
# 3232  [{"id": 53, "name": "Thriller"}, {"id": 80, "n...  680
# 65    [{"id": 18, "name": "Drama"}, {"id": 28, "name...  155
#
#                                                keywords original_language  \
# 1881  [{"id": 378, "name": "prison"}, {"id": 417, "n...                en
# 3337  [{"id": 131, "name": "italy"}, {"id": 699, "na...                en
# 662   [{"id": 825, "name": "support group"}, {"id": ...                en
# 3232  [{"id": 396, "name": "transporter"}, {"id": 14...                en
# 65    [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
#
#                          title  \
# 1881  The Shawshank Redemption
# 3337             The Godfather
# 662                 Fight Club
# ...

# %%
popularity_df = cleaned_df.sort_values('popularity',ascending = False)

# %%
popularity_df[['original_title','popularity','vote_average','weighted_average']].head(20)
# Out:
#                                          original_title  popularity  \
# 546                                             Minions  875.581305
# 95                                         Interstellar  724.247784
# 788                                            Deadpool  514.569956
# 94                              Guardians of the Galaxy  481.098624
# 127                                  Mad Max: Fury Road  434.278564
# 28                                       Jurassic World  418.708552
# 199   Pirates of the Caribbean: The Curse of the Bla...  271.972889
# 82                       Dawn of the Planet of the Apes  243.791743
# 200               The Hunger Games: Mockingjay - Part 1  206.227151
# 88                                           Big Hero 6  203.734590
# 108                                  Terminator Genisys  202.042635
# 26                           Captain America: Civil War  198.372395
# 3865                                           Whiplash  192.528841
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

scaling=MinMaxScaler()

# %%
movie_scaled_df=scaling.fit_transform(cleaned_df[['weighted_average','popularity']])
movie_normalized_df=pd.DataFrame(movie_scaled_df,columns=['weighted_average','popularity'])
movie_normalized_df.head()
# Out:
#    weighted_average  popularity
# 0          0.674339    0.171815
# 1          0.581403    0.158846
# 2          0.436273    0.122635
# 3          0.773054    0.128272
# 4          0.387739    0.050169

# %%
cleaned_df[['normalized_weight_average','normalized_popularity']]= movie_normalized_df
cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   genres                     4803 non-null   object
#  1   id                         4803 non-null   int64
#  2   keywords                   4803 non-null   object
#  3   original_language          4803 non-null   object
#  4   original_title             4803 non-null   object
#  5   overview                   4800 non-null   object
#  6   popularity                 4803 non-null   float64
#  7   production_companies       4803 non-null   object
#  8   production_countries       4803 non-null   object
#  9   release_date               4802 non-null   object
#  10  runtime                    4801 non-null   float64
#  11  spoken_languages           4803 non-null   object
#  12  tagline                    3959 non-null   object
# ...

# %%
cleaned_df['score'] = cleaned_df['normalized_weight_average']*0.7 + cleaned_df['normalized_popularity']*0.3
cleaned_df = cleaned_df.rename(index = str,columns = {'original_title': 'title'})

# %%
cleaned_df[['title','normalized_weight_average','normalized_popularity','score']].sort_values('score',ascending = False).head(20)
# Out:
#                                                   title  \
# 95                                         Interstellar
# 94                              Guardians of the Galaxy
# 1881                           The Shawshank Redemption
# 3337                                      The Godfather
# 65                                      The Dark Knight
# 662                                          Fight Club
# 3865                                           Whiplash
# 3232                                       Pulp Fiction
# 96                                            Inception
# 809                                        Forrest Gump
# 788                                            Deadpool
# 1818                                   Schindler's List
# 2294                                           千と千尋の神隠し
# 329       The Lord of the Rings: The Return of the King
# 2912                                          Star Wars
# 2731                             The Godfather: Part II
# ...

# %%
cleaned_df['score'] = cleaned_df['score']*10

# %%
cleaned_df[['title','normalized_weight_average','normalized_popularity','score']].sort_values('score',ascending = False).head(20)
# Out:
#                                                   title  \
# 95                                         Interstellar
# 94                              Guardians of the Galaxy
# 1881                           The Shawshank Redemption
# 3337                                      The Godfather
# 65                                      The Dark Knight
# 662                                          Fight Club
# 3865                                           Whiplash
# 3232                                       Pulp Fiction
# 96                                            Inception
# 809                                        Forrest Gump
# 788                                            Deadpool
# 1818                                   Schindler's List
# 2294                                           千と千尋の神隠し
# 329       The Lord of the Rings: The Return of the King
# 2912                                          Star Wars
# 2731                             The Godfather: Part II
# ...

# %%
#Content Based Recommender

# %%
cleaned_df['overview'].head(1)
cleaned_df.to_csv("cleaned_df.csv")

# %%
#Using the Tf-Idf Vectorizer
'''
TF-IDF is a statistical measure that evaluates how relevant a word is to a document in a collection of
documents. 
This is done by multiplying two metrics: how many times a word appears in a document, and the inverse 
document frequency of the word across a set of documents.

The term frequency of a word in a document. There are several ways of calculating this frequency, with the 
simplest being a raw count of instances a word appears in a document. Then, there are ways to adjust the 
frequency, by length of a document, or by the raw frequency of the most frequent word in a document.

The inverse document frequency of the word across a set of documents. This means, how common or rare a word
is in the entire document set. The closer it is to 0, the more common a word is. This metric can be 
calculated by taking the total number of documents, dividing it by the number of documents that contain a
word, and calculating the logarithm.
So, if the word is very common and appears in many documents, this number will approach 0. Otherwise, it
will approach 1.

Multiplying these two numbers results in the TF-IDF score of a word in a document. The higher the score, 
the more relevant that word is in that particular document.

Read More At https://www.quora.com/How-does-TfidfVectorizer-work-in-laymans-terms

    
'''
# Out:
# '\nTF-IDF is a statistical measure that evaluates how relevant a word is to a document in a collection of\ndocuments. \nThis is done by multiplying two metrics: how many times a word appears in a document, and the inverse \ndocument frequency of the word across a set of documents.\n\nThe term frequency of a word in a document. There are several ways of calculating this frequency, with the \nsimplest being a raw count of instances a word appears in a document. Then, there are ways to adjust the \nfrequency, by length of a document, or by the raw frequency of the most frequent word in a document.\n\nThe inverse document frequency of the word across a set of documents. This means, how common or rare a word\nis in the entire document set. The closer it is to 0, the more common a word is. This metric can be \ncalculated by taking the total number of documents, dividing it by the number of documents that contain a\nword, and calculating the logarithm.\nSo, if the word is very common and ap
# ...

# %%
cleaned_df = pd.read_csv('cleaned_df.csv')
from sklearn.feature_extraction.text import TfidfVectorizer


tfv = TfidfVectorizer(min_df=3,  max_features=None, 
            strip_accents='unicode', analyzer='word',token_pattern=r'\w{1,}',
            ngram_range=(1, 3),
            stop_words = 'english')

# Filling NaNs with empty string
cleaned_df['overview'] = cleaned_df['overview'].fillna('')

# %%
#we will create a matrix where each row will represent a sentence and each column will be word
#the data at each cell is the importance of a particular word 

tfv_matrix = tfv.fit_transform(cleaned_df['overview'])

# %%
tfv_matrix.shape
# Out:
# (4803, 10417)

# %%
from sklearn.metrics.pairwise import sigmoid_kernel

# Compute the sigmoid kernel
#we are using the sigmoid kernel to compute the similarity between two overviews
sig = sigmoid_kernel(tfv_matrix, tfv_matrix)

# %%
sig[0]
# Out:
# array([0.76163447, 0.76159416, 0.76159416, ..., 0.76159416, 0.76159416,
#        0.76159416])

# %%
#Reverse Mapping of Indices
indices = pd.Series(cleaned_df.index,index = cleaned_df['title']).drop_duplicates()

# %%
indices
# Out:
# title
# Avatar                                         0
# Pirates of the Caribbean: At World's End       1
# Spectre                                        2
# The Dark Knight Rises                          3
# John Carter                                    4
#                                             ...
# El Mariachi                                 4798
# Newlyweds                                   4799
# Signed, Sealed, Delivered                   4800
# Shanghai Calling                            4801
# My Date with Drew                           4802
# Length: 4803, dtype: int64

# %%
indices['The']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4409             try:
# -> 4410                 return libindex.get_value_at(s, key)
#    4411             except IndexError:
#
# pandas\_libs\index.pyx in pandas._libs.index.get_value_at()
#
# pandas\_libs\index.pyx in pandas._libs.index.get_value_at()
#
# pandas\_libs\util.pxd in pandas._libs.util.get_value_at()
#
# pandas\_libs\util.pxd in pandas._libs.util.validate_indexer()
#
# TypeError: 'str' object cannot be interpreted as an integer
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-13181a623924> in <module>
# ----> 1 indices['The']
#
# ...

# %%
indices['The Imitation Game']
# Out:
# 2522

# %%
sig[2522]
# Out:
# array([0.76159416, 0.76159458, 0.76159491, ..., 0.76159533, 0.76159416,
#        0.76159451])

# %%
sig[int(indices['Avatar'])]
# Out:
# array([0.76163447, 0.76159416, 0.76159416, ..., 0.76159416, 0.76159416,
#        0.76159416])

# %%
def give_rec(title, sig=sig):
    # Get the index corresponding to original_title
    idx = int(indices[title])

    # Get the pairwsie similarity scores 
    sig_scores = list(enumerate(sig[idx]))

    # Sort the movies 
    sig_scores = sorted(sig_scores, key=lambda x: x[1], reverse=True)

    # Scores of the 10 most similar movies
    sig_scores = sig_scores[1:11]

    # Movie indices
    movie_indices = [i[0] for i in sig_scores]
    tit = cleaned_df['title'].iloc[movie_indices]
    dat = cleaned_df['release_date'].iloc[movie_indices]

    # Top 10 most similar movies
    return_df = pd.DataFrame(columns=['Title','Year'])
    return_df['Title'] = tit
    return_df['Year'] = dat
    return return_df

# %%
give_rec("Mission: Impossible" )
# Out:
#                                      Title        Year
# 139                Mission: Impossible III  2006-05-03
# 213                 Mission: Impossible II  2000-05-24
# 622                           Body of Lies  2008-10-10
# 153   Mission: Impossible - Ghost Protocol  2011-12-07
# 3943                             Compadres  2016-03-31
# 389                   The Three Musketeers  2011-08-31
# 4689             The Trials Of Darryl Hunt  2007-06-15
# 1332                                  Rush  2013-09-02
# 884                       Zero Dark Thirty  2012-12-19
# 753                           The Sentinel  2006-04-19

# %%
print(np.array(cleaned_df['title']))
p = 'Avatar'in np.array(cleaned_df['title'])
print(p)
# Out:
# ['Avatar' "Pirates of the Caribbean: At World's End" 'Spectre' ...
#  'Signed, Sealed, Delivered' 'Shanghai Calling' 'My Date with Drew']
# True

# %%
p = give_rec("Mission: Impossible")

# %%
names = []
dates = []
for i in range(len(p)):
    names.append(p.iloc[i][0])
    dates.append(p.iloc[i][1])

# %%
names
# Out:
# ['Mission: Impossible III',
#  'Mission: Impossible II',
#  'Body of Lies',
#  'Mission: Impossible - Ghost Protocol',
#  'Compadres',
#  'The Three Musketeers',
#  'The Trials Of Darryl Hunt',
#  'Rush',
#  'Zero Dark Thirty',
#  'The Sentinel']
